# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
import scipy
import PIL
import requests

np.random.seed(613)

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
sns.set_style("whitegrid")
plt.show()

# %%
tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip')
tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')

sns.set_style("darkgrid")

plt.show()

# %%
fig = plt.subplots(figsize=(10, 3))

tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip',
color = 'hotpink',
linestyle = '--',
linewidth = 1,
marker = 'o',
markerfacecolor = 'indigo')

tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')

plt.show()

# %%
tipgraph = sns.scatterplot(data=tips, x='total_bill',
y='tip', style = 'time', hue ='day', palette = ['purple', 'hotpink', 'deepskyblue', 'yellowgreen'])
tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')

plt.show()

# %%
sns.pairplot(
data = tips,
hue = 'day')

# %%
daysplot = sns.relplot(
    data=tips,        # The dataset to use (in this case, 'tips' — a built-in Seaborn dataset)
    x="total_bill",   # Column to plot on the x-axis
    y="tip",          # Column to plot on the y-axis
    hue="sex",        # Use different colors to distinguish between 'sex' categories
    palette = ['blue', 'hotpink'],
    col="day",        # Create separate plots (columns) for each 'day' value
    kind="scatter",   # Type of relational plot — here, a scatter plot
    col_wrap=4        # Wrap the plots into multiple rows after 2 columns
)

# %% [markdown]
# Comments on the interactive graph from: http://benschmidt.org/profGender/#
#
# Types of changes: Immediate
#
# The graph sort the labels of the axes depending on the result the search brings.
#
# Constant: data split into male and female, also the list of subjects
# Changing: the order of the subjects in the axis and correspondent amounts
#
# I can't imagine a better way to display that

# %%
import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph = go.Figure()

graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(
title="Pirate Scores",
xaxis_title="Pirates",
yaxis_title="Score")

graph.show()

# %%
graph = go.Figure()
graph.add_trace(go.Scatter(x=x1, y=y1, mode='markers', # we want points for a scatter plot
marker=dict(
size=15, # point size
color='hotpink', # point colour
opacity=0.5, # point transparency/alpha
line=dict(width=3, color='purple') # point outline
)))
graph.update_layout(
title='Interactive Pirate Plot',
xaxis_title='Pirates',
yaxis_title='Scores',
width=500, height=500)

# %%
#!pip install wordcloud
# Out:
# Collecting wordcloud
#   Using cached wordcloud-1.9.4-cp313-cp313-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (2.2.6)
# Requirement already satisfied: pillow in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Using cached wordcloud-1.9.4-cp313-cp313-win_amd64.whl (300 kB)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.4

# %%
from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)

# generate our wordcloud image
wordcloud = WordCloud(background_color="white", colormap = 'viridis').generate(text)

# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, # remember 'imshow' from when we added pictures to our matplotlib axes
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
#!pip install matplotlib-venn

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
# Out:
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-1.1.2.tar.gz (40 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (3.10.0)
# Requirement already satisfied: numpy in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (2.2.6)
# Requirement already satisfied: scipy in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib-venn) (1.16.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\fabic\miniconda3\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)
# Building wheels for collected packages: matplotlib-venn
#   Building wheel for matplotlib-venn (pyproject.toml): started
#   Building wheel for matplotlib-venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-1.1.2-py3-none-any.whl size=45437 sha256=23a88167b313811a5814b65948ef8754fcfba4f8696e52d331f8570f112cc2c2
#   Stored in directory: c:\users\fabic\appdata\local\pip\cache\wheels\d1\5f\e6\771479559f992b8398265ebf61f8a3d33ca0b8f75552e06ad2
# Successfully built matplotlib-venn
# Installing collected packages: matplotlib-venn
# Successfully installed matplotlib-venn-1.1.2

# %%
A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

# %%
diagram = venn2_unweighted([A, B],
                           set_labels = ('Fruits', 'Pies'),
                           set_colors=("blue", "red"),
                           alpha=0.5
                           )

diagram.get_label_by_id("10").set_text("\n".join(A - B)) # left
diagram.get_label_by_id("11").set_text("\n".join(A & B)) # center
diagram.get_label_by_id("01").set_text("\n".join(B - A)) # right

plt.show()
