# %% [markdown]
# #### 07_accessible_data_visualization
#
# "As professionals and academics who went to communicate our data visually, we have a responsibility to prioritize accessibility"

# %% [markdown]
# activity Alt-text: Woman wearing gloves and lab coat talks to a man in a laboratory.

# %% [markdown]
# Activity: Four types of descriptive content
#
# Level 1: Focus on chart elements such as chart type, title, axis ranges, labels, colours
# Horizontally stacked bar chart, title "The daily routines of famous creative people", horizontal axis range from 12am to 12pm, labels and colours to identify the activity category (sleep, creative work, day job/admin, food/leisure, exercise, other) and the famous persons name
#
# Level 2: Descriptive statistics (eg. mean), outliers, max and min points, correlations, comparing points
# Graph showing the distribution of activities (sleep, creative work, day job/admin, food/leisure, exercise, other) along the hours of the day for different famous creative people. It's possible to notice some concentration of certain activities during specific hours of the day, like sleep from around 10pm to 6am.
#
# Level 3: Complex trends, pattern synthesis, clusters, exceptions, common concepts / Perceptual interpretations of the data
#
#
# Level 4: Context and domain insights, social and political context and explanations / Subjective interpretations that go beyond the data

# %% [markdown]
# #### 08_data_viz_as_advocacy

# %% [markdown]
# - Functions of data visualization for advocacy
# - What data are we seeing? (some arts examples)
# - Credit: Data visualization as the tip of the iceberg (D’Ignazio and Klein (2020) relate the idea of underwater labour to data visualization)

# %% [markdown]
# Assignment 3 discussion / instructions
